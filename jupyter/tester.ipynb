# %%
# %load_ext autoreload
import warnings
warnings.filterwarnings('ignore')

import sys
sys.path.append('../src/boson_cloud_gpu/')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %autoreload 2
# %run ../src/boson_cloud_gpu/main
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/boson_clouds_gpu/src/boson_cloud_gpu/main.py:69
#      58     # idx = 600
#      59
#      60     # bins = cupy.asnumpy(bins)[idx]
#    (...)
#      64     # plt.show()
#      65     # plt.plot(counts, ".")
#      68 if __name__ == "__main__":
# ---> 69     main()
#      70     # print(benchmark(main, n_repeat=100, n_warmup=5, name="gpu_v3.0"))
#
# File ~/boson_clouds_gpu/src/boson_cloud_gpu/main.py:51, in main()
#      41 boson_masses = generation.bosons.get_bosons()
#      43 frequencies, amplitudes = simulation.get_signals(
#      44     bh_masses,
#      45     bh_ages_yrs,
#    (...)
#      48     boson_masses,
#      49 )
# ---> 51 counts, bins = simulation.cupy_histograms(
#      52     frequencies,
#      53     amplitudes,
#      54     100,
#      55     10,
#      56 )
#
# ...
